# %% [markdown]
# # Organizacion de Datos :: 75.06
# ## Word University Ranking (Data: CWUR)

# %% [markdown]
# #### cwurData.csv dataset (source: https://www.kaggle.com/mylesoneill/world-university-rankings)
#
# - world_rank - world rank for university.
# - institution - name of university.
# - country - country of each university.
# - national_rank - rank of university within its country.
# - quality_of_education - rank for quality of education.
# - alumni_employment - rank for alumni employment.
# - quality_of_faculty - rank for quality of faculty.
# - publications - rank for publications.
# - influence - rank for influence.
# - citations - rank for citations.
# - broad_impact - rank for broad impact (only available for 2014 and 2015)
# - patents - rank for patents.
# - score - total score, used for determining world rank.
# - year - year of ranking (2012 to 2015).

# %%
import pandas as pd
from pandas import Series,DataFrame
import numpy as np

# %% [markdown]
# ## Creacion de Data Frame

# %%
wur = pd.read_csv("data/world-university-rankings/cwurData.csv")
# vemos los primeros registros del data frame
wur.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score  year
# 0             1          1          1           NaN        5  100.00  2012
# 1            12          4          4           NaN        1   91.67  2012
# 2             4          2          2           NaN       15   89.50  2012
# 3            16         16         11           NaN       50   86.17  2012
# 4            37         22         22           NaN       18   85.21  2012

# %%
# vemos una descripcion del contenido del data frame
wur.describe()
# Out:
#         world_rank  national_rank  quality_of_education  alumni_employment  \
# count  2200.000000    2200.000000           2200.000000        2200.000000
# mean    459.590909      40.278182            275.100455         357.116818
# std     304.320363      51.740870            121.935100         186.779252
# min       1.000000       1.000000              1.000000           1.000000
# 25%     175.750000       6.000000            175.750000         175.750000
# 50%     450.500000      21.000000            355.000000         450.500000
# 75%     725.250000      49.000000            367.000000         478.000000
# max    1000.000000     229.000000            367.000000         567.000000
#
#        quality_of_faculty  publications    influence    citations  \
# count         2200.000000   2200.000000  2200.000000  2200.000000
# mean           178.888182    459.908636   459.797727   413.417273
# std             64.050885    303.760352   303.331822   264.366549
# min              1.000000      1.000000     1.000000     1.000000
# 25%            175.750000    175.750000   175.750000   161.000000
# 50%            210.000000    450.500000   450.500000   406.000000
# 75%            218.000000    725.000000   725.250000   645.000000
# max            218.000000   1000.000000   991.000000   812.000000
#
#        broad_impact      patents        score         year
# count   2000.000000  2200.000000  2200.000000  2200.000000
# mean     496.699500   433.346364    47.798395  2014.318182
# std      286.919755   273.996525     7.760806     0.762130
# min        1.000000     1.000000    43.360000  2012.000000
# 25%      250.500000   170.750000    44.460000  2014.000000
# 50%      496.000000   426.000000    45.100000  2014.000000
# 75%      741.000000   714.250000    47.545000  2015.000000
# max     1000.000000   871.000000   100.000000  2015.000000

# %%
# filtramos valores del data frame y creamos uno nuevo solamente con informacion de argentina
wur_ar = wur[wur['country']=='Argentina']
wur_ar.head()
# Out:
#       world_rank                      institution    country  national_rank  \
# 577          378       University of Buenos Aires  Argentina              1
# 940          741  National University of La Plata  Argentina              2
# 1096         897   National University of Córdoba  Argentina              3
# 1177         978   National University of Rosario  Argentina              4
# 1566         367       University of Buenos Aires  Argentina              1
#
#       quality_of_education  alumni_employment  quality_of_faculty  \
# 577                    192                477                 176
# 940                    355                476                 210
# 1096                   355                478                 210
# 1177                   355                478                 210
# 1566                   126                500                 180
#
#       publications  influence  citations  broad_impact  patents  score  year
# 577            268        348        363         349.0      737  45.66  2014
# 940            546        523        406         703.0      737  44.59  2014
# 1096           713        818        609         849.0      737  44.39  2014
# 1177           976        811        800         956.0      737  44.29  2014
# 1566           276        350        321         344.0      871  45.37  2015

# %%
# filtramos el data frame y nos quedamos solamente con informacion de USA
wur_us = wur[wur['country']=='USA']
wur_us.describe()
# Out:
#        world_rank  national_rank  quality_of_education  alumni_employment  \
# count  573.000000     573.000000            573.000000         573.000000
# mean   290.528796      97.790576            218.476440         257.514834
# std    269.058442      68.818791            136.698989         196.649119
# min      1.000000       1.000000              1.000000           1.000000
# 25%     53.000000      36.000000             91.000000          84.000000
# 50%    202.000000      86.000000            235.000000         208.000000
# 75%    489.000000     158.000000            355.000000         478.000000
# max    969.000000     229.000000            367.000000         567.000000
#
#        quality_of_faculty  publications   influence   citations  broad_impact  \
# count          573.000000    573.000000  573.000000  573.000000    458.000000
# mean           145.228621    339.567190  280.134380  257.055846    348.262009
# std             80.469134    310.034057  256.536065  248.109461    267.587351
# min              1.000000      1.000000    1.000000    1.000000      1.000000
# 25%             67.000000     60.000000   52.000000   46.000000    105.250000
# 50%            210.000000    234.000000  201.000000  161.000000    305.500000
# 75%            218.000000    591.000000  484.000000  406.000000    565.000000
# max            218.000000    993.000000  974.000000  812.000000    946.000000
#
#           patents       score         year
# count  573.000000  573.000000   573.000000
# mean   296.279232   51.839860  2014.097731
# std    264.791947   11.915425     0.946587
# min      1.000000   43.880000  2012.000000
# 25%     68.000000   44.910000  2014.000000
# 50%    194.000000   46.980000  2014.000000
# 75%    502.000000   52.890000  2015.000000
# max    871.000000  100.000000  2015.000000

# %% [markdown]
# ## Bokeh
#
# Bokeh es una biblioteca de visualizacion interactiva para python que apunta a presentacion en web browsers modernos.
#
# Recomendamos para comenzar a crear visualizaciones visitar la [Bokeh User Guide](http://bokeh.pydata.org/en/latest/docs/user_guide.html#userguide).
#
# Durante la clase trabajaremos con las High-level charts pero se pueden realizar visualizaciones mas complejas.

# %%
from bokeh.plotting import *
from bokeh.charts import *
from bokeh.io import output_notebook

# output for jupyter
output_notebook()

from bokeh.charts import defaults

defaults.width = 500
defaults.height = 500
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="07a71be9-36ca-4170-9edb-492c40b03f54">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### Bar Charts

# %%
# mostrar variaciones en data frame por pais y top 10
p = Bar(wur_ar, 'institution', values='broad_impact', title="Broad Impact per Year", 
        group="year", xlabel="Institucion", ylabel="Broad Impact")

show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="07d59264-8f35-45cf-bbc2-26d07e35d696"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#07d59264-8f35-45cf-bbc2-26d07e35d696").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("07d59264-8f35-45cf-bbc2-26d07e35d696");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '07d59264-8f35-45cf-bbc2-26d07e35d696' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"3b9ceec0-579a-4915-934a-51a9e1e8098e":{"roots":{"references":[{"attributes":{"data_source":{"id":"78fd3d37-1508-44fc-92ed-e22cdd79e3e0","type":"ColumnDataSource"},"glyph":{"id":"784e1ec0-a6c9-4c52-9531-77c42f42ad6d","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"5fff71a0-6523-4ad8-93aa-9e8e25abb4ff","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"institution":"National University of La Plata","year":2014}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[703.0],"institution":["National University of La Plata"],"label":[{"institution":"National University of La Plata","year":2014}],"line_alpha":[1.0],"line_color":["white"],"width":[0.2],"x":["National University of La Plata:0.333333333333"],"y":[351.5],"year":[2014]}},"id":"86a742b9-60df-4dde-8f46-915986b2b1f2","type":"ColumnDataSource"},{"attributes":{},"id":"5ad875d1-b22d-4257-8da8-dd5dde5f7e11","type":"CategoricalTickFormatter"},{"attributes":{"axis_label":"Institucion","formatter":{"id":"5ad875d1-b22d-4257-8da8-dd5dde5f7e11","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"0aa258d2-2b8b-4003-820d-fe778e0a06bb","subtype":"Chart","type":"Plot"},"ticker":{"id":"ef896fe5-ba77-45ce-b851-b4699416d68b","type":"CategoricalTicker"}},"id":"96342217-2ecb-43f1-a3c6-a07cae6b9200","type":"CategoricalAxis"},{"attributes":{"data_source":{"id":"1d4deafc-bbd3-4ff6-8d7a-1b6869b47e86","type":"ColumnDataSource"},"glyph":{"id":"d1108774-7547-42af-b7a2-0748c4118ebe","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"d798fe72-67dc-4ac0-8c5b-d0fbd949fb38","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d46ed8b0-bbf6-4ef6-a13c-f13201a17162","type":"Rect"},{"attributes":{"plot":{"id":"0aa258d2-2b8b-4003-820d-fe778e0a06bb","subtype":"Chart","type":"Plot"}},"id":"480574a4-599b-48a9-8660-40e656a8991e","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"e8c4ef92-56ad-4b40-b2a1-46ff47b64acf","type":"ColumnDataSource"},"glyph":{"id":"12d4e638-30ba-4528-ae97-9b23997c49c3","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"3087b01f-f4e2-42ba-b8d8-5fc5d06312b1","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"b841ea2a-b09a-4b4f-abff-83694961c968","type":"PanTool"},{"id":"480574a4-599b-48a9-8660-40e656a8991e","type":"WheelZoomTool"},{"id":"b062777d-e8d7-41ca-8af6-cf43ef844a99","type":"BoxZoomTool"},{"id":"a491a235-ac14-44b9-af78-6a3e1db7d02b","type":"SaveTool"},{"id":"ea534db8-997f-4ab4-8ab8-eafd3a54d938","type":"ResetTool"},{"id":"f217c486-df87-4323-903e-95e06825ffff","type":"HelpTool"}]},"id":"293efcd9-d1ff-4680-aa2f-40fbde7518ed","type":"Toolbar"},{"attributes":{"callback":null,"factors":["National University of C\u00f3rdoba","National University of La Plata","National University of Rosario","University of Buenos Aires"]},"id":"b049cce8-acb8-47a5-9418-398b37740966","type":"FactorRange"},{"attributes":{"data_source":{"id":"46d07d1d-6785-41d6-9c69-f52ea1abd25d","type":"ColumnDataSource"},"glyph":{"id":"5eee66ae-1020-4e98-af41-321ffc61d57d","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"93440a04-b763-4f2e-80e5-31f67d7ed7d3","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"0aa258d2-2b8b-4003-820d-fe778e0a06bb","subtype":"Chart","type":"Plot"},"ticker":{"id":"d8c746f6-ba59-4195-9aaa-9d0129e1ed23","type":"BasicTicker"}},"id":"73f91301-2888-4dc3-ac3c-d75d2b97ba13","type":"Grid"},{"attributes":{"callback":null,"column_names":["line_color","lin ...

# %% [markdown]
# ## Histogram

# %%
# mostrar variaciones de bins
# mostrar metodo de agregacion
h = Histogram(wur, values='quality_of_education', color="green", title="US Quality of Education Rank Distribution on 2015", bins=20)
show(h)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="7ee95d8f-51f7-4959-860c-fafcc7eff82e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#7ee95d8f-51f7-4959-860c-fafcc7eff82e").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7ee95d8f-51f7-4959-860c-fafcc7eff82e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7ee95d8f-51f7-4959-860c-fafcc7eff82e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"a881ba7f-1d40-4541-8be3-eefa813d9103":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c6e76543-42a8-4da4-b8bd-c0c876d8979d","type":"Rect"},{"attributes":{"data_source":{"id":"d471c55a-6c91-47c3-852e-87fea5620d7a","type":"ColumnDataSource"},"glyph":{"id":"f8679358-6bdd-4bc5-8534-a83f3f542030","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"5de488ca-da70-4dd9-9d57-1788062a41f4","type":"GlyphRenderer"},{"attributes":{},"id":"c15512c1-1886-49f2-a51e-388d6d8d9cb3","type":"ToolEvents"},{"attributes":{"plot":null,"text":"US Quality of Education Rank Distribution on 2015"},"id":"51b4f185-4325-41c3-840f-8a5a1e32b810","type":"Title"},{"attributes":{"plot":{"id":"745b9d21-89b3-45cb-a3ab-0837ff353d8e","subtype":"Chart","type":"Plot"}},"id":"7b92eaee-5961-4106-baef-f74bbe14b181","type":"ResetTool"},{"attributes":{"callback":null,"end":1434.4},"id":"b06ccc23-d694-4f70-bf0f-5cc80f618286","type":"Range1d"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"34e3e31d-7f00-4d1b-b1ba-a9c6f93e2fcc","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"dafa1441-b26c-45c9-a71b-8955dd782198","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(74.2, 92.5]"],"color":["green"],"fill_alpha":[0.8],"height":[56.0],"label":["(74.2, 92.5]"],"line_alpha":[1.0],"line_color":["black"],"width":[18.299999999999997],"x":["83.35"],"y":[28.0]}},"id":"bd1f7126-69d8-439a-86a6-490f79df789d","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"dc3859b7-a9c7-4f5b-a607-825a7e753ae0","type":"ColumnDataSource"},"glyph":{"id":"dafa1441-b26c-45c9-a71b-8955dd782198","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"5f949a77-ad19-4b19-9410-e2901ce754b6","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"745b9d21-89b3-45cb-a3ab-0837ff353d8e","subtype":"Chart","type":"Plot"}},"id":"f113fc6a-7e08-49be-b148-b84c893d54f7","type":"HelpTool"},{"attributes":{"axis_label":"quality_of_education","formatter":{"id":"f2db9df6-eed0-499e-bba6-7c4eaf483fab","type":"BasicTickFormatter"},"plot":{"id":"745b9d21-89b3-45cb-a3ab-0837ff353d8e","subtype":"Chart","type":"Plot"},"ticker":{"id":"2054ccde-ae85-4251-a810-702346d2f2ad","type":"BasicTicker"}},"id":"4a9aa423-bc56-4260-9e52-9201bf41c187","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(184.0, 202.3]"],"color":["green"],"fill_alpha":[0.8],"height":[38.0],"label":["(184.0, 202.3]"],"line_alpha":[1.0],"line_color":["black"],"width":[18.30000000000001],"x":["193.15"],"y":[19.0]}},"id":"67fd1811-1d2c-4133-95ed-32ee72bdb62b","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f32fe474-a4e8-463a-85c8-c0ba28c59332","type":"Rect"},{"attributes":{"data_source":{"id":"f19d2e57-5fb1-4661-b62f-f8c76b932b39","type":"ColumnDataSource"},"glyph":{"id":"d990e5b3-f296-4625-9447-d370769f17a8","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id": ...

# %%
# mostrar separacion de por cambio de escalas del 2013 en adelante
h = Histogram(wur_us, values='quality_of_education', color='year', 
              title="US Quality of Education Rank Distribution", bins=20, xlabel="Quality of Education")
show(h)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="e802ea34-617d-4413-8853-18c370d4d462"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#e802ea34-617d-4413-8853-18c370d4d462").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e802ea34-617d-4413-8853-18c370d4d462");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e802ea34-617d-4413-8853-18c370d4d462' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"1f535ce4-08b3-430a-8ff8-3adf0624bbab":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3ae45459-64fc-415a-bf0e-243d62d12e94","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"866b80ed-ffbd-4bbf-b9be-01e36036183c","type":"Rect"},{"attributes":{"data_source":{"id":"b70d2d8c-163b-48a7-a6f2-55e7963b97f0","type":"ColumnDataSource"},"glyph":{"id":"45ce5f2f-5ce2-4b31-a965-6c1d1de83ead","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"9a161e40-4e33-4053-89dc-1ec00e703009","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c77cd956-ac6c-4f0c-9e19-d93a49ace661","type":"Rect"},{"attributes":{"data_source":{"id":"8b04bd5e-b5a2-47a2-bd9e-53eaa65efcbe","type":"ColumnDataSource"},"glyph":{"id":"1bc6f596-9604-4e8a-b86b-e4c1a36ba7eb","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"bcc914b7-fd3b-479c-a884-216675969421","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"fc7e8d58-7162-4dbc-afff-306e3d0e3d2e","type":"ColumnDataSource"},"glyph":{"id":"bf627ed8-aae9-446e-9cf6-6df00b3272d7","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"4163857e-f43c-4ae6-b54e-57957b670236","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"aff1b7f2-f568-4c68-9b08-22f389163a83","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(110.8, 129.1]"],"color":["#df5320"],"fill_alpha":[0.6],"height":[2.0],"label":["(110.8, 129.1]"],"line_alpha":[1.0],"line_color":["black"],"width":[18.299999999999983],"x":["119.95"],"y":[1.0]}},"id":"426b7be5-e442-493f-aee0-d4a7b1b2e905","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"33328f68-cac8-4aa7-b311-38c11170f333","type":"ColumnDataSource"},"glyph":{"id":"4dd0542b-5995-452d-96eb-4fc1a6a67804","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"9f146a4f-7e07-4bbd-b554-c657648b9268","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(76.0, 81.0]"],"color":["#f22c40"],"fill_alpha":[0.6],"height":[2.0],"label":["(76.0, 81.0]"],"line_alpha":[1.0],"line_color":["black"],"width":[5.0],"x":["78.5"],"y":[1.0]}},"id":"41eab90d-f03a-45c6-9f91-ce6353410021","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(26.0, 31.0]"],"color":["#f22c40"],"fill_alpha":[0.6],"height":[3.0],"label":["(26.0, 31.0]"],"line_alpha":[1.0],"line_color":["black"],"width":[5.0],"x":["28.5"],"y":[1.5]}},"id":"e979a5a8-92f8-4b78-9231-bbd609dd59a3","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ca9b14c4-8891-44fe-a0bb-dc7c7cca ...

# %% [markdown]
# ## Scatter Plot

# %%
s = Scatter(wur_us[wur_us['year'] > 2013], x='score', y='world_rank', title="Score vs. World Rank",
            xlabel="Score (0-100)", ylabel="World Rank", color='year', legend='top_right')

show(s)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="a384496c-9011-41c9-88da-dc3c7cea3449"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#a384496c-9011-41c9-88da-dc3c7cea3449").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a384496c-9011-41c9-88da-dc3c7cea3449");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a384496c-9011-41c9-88da-dc3c7cea3449' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"d81e668f-1d6c-4501-96cf-7553b8d9fb5d":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"a0ff696d-c3b6-4245-80c9-30e760ccb772","type":"PanTool"},{"id":"dd96f51d-7e48-46e7-8a25-8003ae31f919","type":"WheelZoomTool"},{"id":"479596e6-cbbd-461b-bf0f-2a7147c1db94","type":"BoxZoomTool"},{"id":"2d46c913-d4d0-4991-9b99-30abb2ed41da","type":"SaveTool"},{"id":"b360266e-3156-4610-97e9-6c4488c1dcc3","type":"ResetTool"},{"id":"7481a27f-efb1-4eb9-b02c-2f51895f70d5","type":"HelpTool"}]},"id":"d7b31c3a-194e-4155-8e9f-f1fc8c8e3e3c","type":"Toolbar"},{"attributes":{},"id":"e9119218-b4eb-4fe0-b91d-74d67cb0871a","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"38c5cb95-ce39-4706-81be-1d5dfe968363","subtype":"Chart","type":"Plot"},"ticker":{"id":"45918b95-f9f6-442d-9a8b-313d9a9f64ac","type":"BasicTicker"}},"id":"748ec8d5-d6c5-4482-b07c-483334eaac6f","type":"Grid"},{"attributes":{},"id":"8834766c-487c-4549-a384-e9256f1d58ea","type":"BasicTicker"},{"attributes":{"plot":{"id":"38c5cb95-ce39-4706-81be-1d5dfe968363","subtype":"Chart","type":"Plot"}},"id":"dd96f51d-7e48-46e7-8a25-8003ae31f919","type":"WheelZoomTool"},{"attributes":{"callback":null,"end":1065.8,"start":-95.80000000000001},"id":"238f4bf2-9763-4b0c-99c1-7d8d540d5f90","type":"Range1d"},{"attributes":{"overlay":{"id":"9921e5c5-dc1f-4377-b158-4d0f89618571","type":"BoxAnnotation"},"plot":{"id":"38c5cb95-ce39-4706-81be-1d5dfe968363","subtype":"Chart","type":"Plot"}},"id":"479596e6-cbbd-461b-bf0f-2a7147c1db94","type":"BoxZoomTool"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"5022dc26-0c00-45fa-913f-5a9fc5859c85","type":"Circle"},{"attributes":{"plot":{"id":"38c5cb95-ce39-4706-81be-1d5dfe968363","subtype":"Chart","type":"Plot"}},"id":"2d46c913-d4d0-4991-9b99-30abb2ed41da","type":"SaveTool"},{"attributes":{"plot":{"id":"38c5cb95-ce39-4706-81be-1d5dfe968363","subtype":"Chart","type":"Plot"}},"id":"a0ff696d-c3b6-4245-80c9-30e760ccb772","type":"PanTool"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year":2014},{"year": ...

# %%
wur_2015 = wur[wur['year'] == 2015]
wur_2015_neighboors = wur_2015[(wur_2015['country'] == 'Argentina') | (wur_2015['country'] == 'Brazil') | (wur_2015['country'] == 'Chile') | (wur_2015['country'] == 'Uruguay')]
s = Scatter(wur_2015_neighboors, 
            x='score', y='world_rank', title="Score vs. World Rank",
            xlabel="Score (0-100)", ylabel="World Rank", color='country', legend='top_right')
show(s)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="4b66c8f1-0b4f-4980-be41-46e93a514d99"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#4b66c8f1-0b4f-4980-be41-46e93a514d99").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4b66c8f1-0b4f-4980-be41-46e93a514d99");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4b66c8f1-0b4f-4980-be41-46e93a514d99' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"1d6db2b8-a7c8-43f9-b177-ce4ef7ae9313":{"roots":{"references":[{"attributes":{"callback":null,"end":1084.6,"start":45.39999999999999},"id":"29c58d9b-cf7f-4caf-8bda-57186250cbf8","type":"Range1d"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#df5320"},"line_color":{"value":"#df5320"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"12b35d7f-c514-4daf-b557-460c9829d2b3","type":"Circle"},{"attributes":{"callback":null,"end":49.838,"start":43.502},"id":"a2fdc358-c87d-41e0-bcd9-c7bd3c14ca02","type":"Range1d"},{"attributes":{},"id":"cd2aeeea-6908-48ec-ba3c-3fd2dfc75188","type":"ToolEvents"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"1b5ac7aa-bd8a-41aa-9b11-3a2cf080feff","type":"PanTool"},{"id":"3a2f6f68-ed4a-4370-abd2-716dcd40dee9","type":"WheelZoomTool"},{"id":"e31b593b-6506-4005-92b9-2f07fe68c83c","type":"BoxZoomTool"},{"id":"9d9d82b6-928e-444e-a844-b3b2fc8e5f00","type":"SaveTool"},{"id":"15a42d1f-e3aa-4744-b0f9-ab5e334fd4b9","type":"ResetTool"},{"id":"169a71f6-cb64-45b1-9642-d5ddce99f44f","type":"HelpTool"}]},"id":"5e2e7cea-b0bb-4ff7-84fd-f00fed096983","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"country":"Brazil"},{"country":"Brazil"},{"country":"Brazil"},{"country":"Brazil"},{"country":"Brazil"},{"country":"Brazil"},{"country":"Brazil"},{"country":"Brazil"},{"country":"Brazil"},{"country":"Brazil"},{"country":"Brazil"},{"country":"Brazil"},{"country":"Brazil"},{"country":"Brazil"},{"country":"Brazil"},{"country":"Brazil"},{"country":"Brazil"},{"country":"Brazil"}],"country":["Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil"],"x_values":[49.31,45.72,45.14,44.7,44.55,44.53,44.41,44.21,44.12,44.12,44.12,44.1,44.09,44.09,44.07,44.05,44.03,44.03],"y_values":[132,322,404,526,583,589,664,826,915,918,920,934,939,941,961,974,992,998]}},"id":"747b7e6e-fafb-44e0-9f9a-93599c5a8aae","type":"ColumnDataSource"},{"attributes":{},"id":"7d3ad211-b6a2-472c-9d7c-b240a5cd898b","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"27664cc2-277a-496b-a83d-6d903a013857","subtype":"Chart","type":"Plot"},"ticker":{"id":"751a86cd-31b5-4687-a60d-a79ba130d7e4","type":"BasicTicker"}},"id":"0103371e-540d-4e43-8be1-e0827727bcb5","type":"Grid"},{"attributes":{},"id":"751a86cd-31b5-4687-a60d-a79ba130d7e4","type":"BasicTicker"},{"attributes":{"data_source":{"id":"747b7e6e-fafb-44e0-9f9a-93599c5a8aae","type":"ColumnDataSource"},"glyph":{"id":"c81237fc-683c-4772-87b8-b28dc2431b0d","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"132efc33-bf2e-4c58-bb8d-9820d18c757c","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"27664cc2-277a-496b-a83d-6d903a013857","subtype":"Chart","type":"Plot"},"ticker":{"id":"c3caf6fb-86a0-4e88-b301-b6e9b67c86e8","type":"BasicTicker"}},"id":"70343682-a0b2-4a8b-ae4b-2c3a2ffd00de","type":"Grid"},{"attributes":{"plot":{"id":"27664cc2-277a-496b-a83d-6d903a013857","subtype":"Chart","type":"Plot"}},"id":"169a71f6-cb64-45b1-9642-d5ddce99f44f","type":"HelpTool"},{"attributes":{},"id":"0484d81d-8e4a-48a6-ae31-fa2e183174f4","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"fefdeb06-9744-4edc-9c9b-ae47b2ac4494","type":"BoxAnnotation"},"plot":{"id":"27664cc2-277a-496b-a83d-6d903a013857","subtype":"Chart","type":"Plot"}},"id":"e31b593b-6506-4005-92b9-2f07fe68c83c","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"a3e87394-9509-4f66-b45c-445c91bcacbd","type":"ColumnDataSource"},"glyph":{"id":"127973a8-32fb-4ac1-8d7b-0bd078428f92","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"cf2d6c4a-7769-4562-a092-cd6c3214b862","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"27664cc2-277a-496b-a83d-6d903a013857","subty ...

# %% [markdown]
# ## Boxplot

# %%
from bokeh.charts import BoxPlot, output_file, show
from bokeh.sampledata.autompg import autompg as df

# values como world_rank, score

p = BoxPlot(wur_2015_neighboors, values='world_rank', label='country',
            title="Score Variation (grouped by country)", legend='bottom_right', color='country')

show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="9dbfa871-9b75-45d0-a4c6-4ee8eb36ba4b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#9dbfa871-9b75-45d0-a4c6-4ee8eb36ba4b").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9dbfa871-9b75-45d0-a4c6-4ee8eb36ba4b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9dbfa871-9b75-45d0-a4c6-4ee8eb36ba4b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"612ecb71-5a0c-4475-a059-ffdbcd2b95cf":{"roots":{"references":[{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"5f4c2ee3-05eb-42bb-b857-8fc357a9de40","type":"Segment"},{"attributes":{"data_source":{"id":"e6d4b191-1c4a-45a3-b15f-d4908e93955b","type":"ColumnDataSource"},"glyph":{"id":"d5c58c93-7e57-4819-9220-2370a1a46cb1","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"6a43b25b-e8ba-4612-ad5d-a740d3808f4a","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3b134a5c-1380-4d18-8540-ae22d7459287","type":"Rect"},{"attributes":{"plot":{"id":"74b8f3f1-3d19-4b10-b6d1-6a337ec2e5a0","subtype":"Chart","type":"Plot"}},"id":"54ba34b4-df64-45ef-8a90-30bed65d71a3","type":"PanTool"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"country":"Uruguay"}],"color":["#df5320"],"country":["Uruguay"],"fill_alpha":[0.8],"height":[0.0],"label":[{"country":"Uruguay"}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["Uruguay"],"y":[867.0]}},"id":"1977d19b-cab4-477f-818e-763a608c1192","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"country":"Chile"}],"color":["#407ee7"],"country":["Chile"],"fill_alpha":[0.8],"height":[228.75],"label":[{"country":"Chile"}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["Chile"],"y":[729.375]}},"id":"14741b0a-0313-4fd3-87f5-c977c6f055b3","type":"ColumnDataSource"},{"attributes":{"axis_label":"Country","formatter":{"id":"6fa36d5f-162f-4b1d-8016-a2175e8ebace","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"74b8f3f1-3d19-4b10-b6d1-6a337ec2e5a0","subtype":"Chart","type":"Plot"},"ticker":{"id":"832ee063-69a7-482a-9805-89b2ce53c14e","type":"CategoricalTicker"}},"id":"a74af9e7-51c8-4d0f-aa38-62cf740e5a17","type":"CategoricalAxis"},{"attributes":{},"id":"6fa36d5f-162f-4b1d-8016-a2175e8ebace","type":"CategoricalTickFormatter"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"35e83ca0-4dfe-4a71-b7ea-05388dcd930d","type":"Rect"},{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"ddd7a6d7-85b6-40a3-9107-afd72629600a","type":"Segment"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"01c95616-1773-4012-ba2b-3efe72439650","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d43fd1b8-b247-4019-9385-e134dfc66c6e","type":"Rect"},{"attributes":{"callback":null,"end":1054.5},"id":"e64e2c49-4a06-4d14-8364-0beb358992ea","type":"Range1d"},{"attributes":{},"id":"832ee063-69a7-482a-9805-89b2ce53c14e","type":"CategoricalTicker"},{"attributes":{"data_source":{"id":"1977d19b-cab4-477f-818e-763a608c1192","type":"ColumnDataSource"},"glyph":{"id":"3b134a5c-1380-4d18-8540-ae22d7459287","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"1987ef01-c851-4ae4-8da6-da5584b44021","type":"Gly ...
